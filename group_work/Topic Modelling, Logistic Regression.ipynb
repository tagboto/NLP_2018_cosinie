# %% [markdown]
# #  Natural Language Processing Group Project
# ## Topic Modelling - Logistic Regression Implementation
#
# Name: Our Group

# %%
import re
import nltk
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report

# %%
def read_data():
    question_data = pd.read_csv('Questions.txt', sep='\t', names=['questions'], index_col= None, header = 0 )
    topics_data = pd.read_csv('Topics.txt', sep='\t', names=['topics'], index_col= None, header = 0 )
        
    #After getting the data I combine them into 1 data frame to get questions and topics
    q_t_data = pd.concat([question_data,topics_data],axis=1)
    
    #I then return the questions and topics as a list
    return q_t_data.questions.values.tolist(), q_t_data.topics.values.tolist()

# %%
# I used stemming only on questions to remove any unncessary words. 
def stemming(questions):
    lancaster_stemmer = LancasterStemmer()
    n_questions = []
    for question in questions:
        n_questions.append(' '.join(lancaster_stemmer.stem(token)for token in nltk.word_tokenize(question)))
    return(n_questions)

# %%
def lemming(questions):
    wordnet_lemmatizer = WordNetLemmatizer()
    n_questions = []
    for question in questions:
        n_questions.append(' '.join(wordnet_lemmatizer.lemmatize(token)for token in nltk.word_tokenize(question)))
    return(n_questions)

# %%
def lr_train(questions,labels):

    #N-gram model that comes up with features or occurances of words
    
    count_vect = CountVectorizer(stop_words='english')
    tf_transform = TfidfTransformer()
    
    X_train_counts = count_vect.fit_transform(r for r in questions)
    
    # This is to scale down impact of tkens that occur very frequently and arent
    #very informative.
    #Term Frequency time Inverse Document Frequency

    X_train_counts = count_vect.fit_transform(r for r in questions)
    
    # This is to scale down impact of tkens that occur very frequently and arent
    #very informative.
    #Term Frequency time Inverse Document Frequency
    
    X_train_tf = tf_transform.fit_transform(X_train_counts)
    
    #splitting data into test and training sets
    X_train, X_test, Y_train, Y_test =train_test_split(X_train_tf,labels, random_state = 35 , train_size =0.80, test_size =0.20)
 

    #MAKING THE MODEL
    lrn = LogisticRegression()
    model = lrn.fit(X_train, Y_train)
    #array.reshape(-1, 1)
    
    return lrn, tf_transform, count_vect, model, X_test, Y_test

# %%
 def lr_test(test_file,questions,labels):
    lrn,tf_transform, count_vect, model, X_test, Y_test = lr_train(questions,labels)
   
  
    
    #Now using the test set I need to know if I'm right
    #test_data = []
    #for line in open(test_file):
    #    r2 = re.compile(r'[^a-zA-Z0-9]', re.MULTILINE)
    #    s = r2.sub(' ', line)
    #    test_data.append(s)
    
    
    #test_data = stemming(test_data)
    #test_data = lemming(test_data)
        
    
    
    
    #Making sentiment classification
    #for i in range (len(test_data)):
        #X_pred_counts = count_vect.transform(test_data)
        #X_pred_tf = tf_transform.transform(X_pred_counts)
        #predictions = lrn.predict(X_pred_tf)
                
                        
    #Evaluating the model using the classification report function form sklearn

    predicted = model.predict(X_test)    
    print("The accuracy of this test is: " ,accuracy_score(Y_test, predicted)*100) 

    print("This is a more detailed report of the classifiers performance: \n" ,classification_report(Y_test, predicted))
    
    return(predicted,"\n")

# %%
def my_LR():
    questions, topics = read_data()
    questions = stemming(questions)
    questions = lemming(questions)
    lr_test('test_sentences2.txt',questions, topics)

# %%
def results(classifier, version, predictL):
    file_name = open("results-"+classifier+"-"+version+".txt", w)
    #file_name.write("Ouput: "+"\n")
    
    for label in predictL[0]:
        file_name.write(str(label)+"\n")

# %%
my_LR()
# Out:
# The accuracy of this test is:  68.77394636015326
# This is a more detailed report of the classifiers performance:
#                                                    precision    recall  f1-score   support
#
#                                  Abraham_Lincoln       1.00      0.50      0.67         6
#                                 Alessandro_Volta       0.80      0.80      0.80         5
#                                            Alexa       0.62      1.00      0.77        10
#                                  Amedeo_Avogadro       1.00      0.71      0.83         7
#                                   Anders_Celsius       0.86      0.60      0.71        10
#                                          Animals       0.30      0.50      0.37         6
#                                    Apple HomePod       1.00      0.60      0.75         5
# Applications, Admissions, Transcripts, Transfers       0.00      0.00      0.00         1
#                                  Arabic_language       0.00      0.00      0.00         1
#                          Artificial Intelligence       0.56      0.83      0.67        12
#                                       BLOCKCHAIN       0.64      0.64      0.64        11
#                                              Bee       0.00      0.00      0.00         2
#                                          Beijing       0.00      0.00      0.00         3
#                                           Berlin       1.00      0.60      0.75         5
#                                    Blaise_Pascal       1.00      0.25      0.40         4
#                                        Butterfly       0.00      0.00      0.00         1
#                                  Calvin_Coolidge       1.00      0.67      0.80         6
#                                           Canada       1.00      0.60      0.75         5
#                                             Cars       0.80      1.00      0.89         4
#                                            Cello       1.00      0.67      0.80         3
#                      Charles-Augustin_de_Coulomb       1.00      1.00      1.00         3
#                                 Chinese_language       1.00      0.29      0.44         7
#                                  Cloud Computing       0.63      1.00      0.77        12
#                                Common IT Issues        0.62      0.83      0.71         6
#          Cost, Fees, Financial Aid, Compensation       0.00      0.00      0.00         1
#                                           Cougar       0.00      0.00      0.00         2
#                                           Cymbal       1.00      0.86      0.92         7
#                                            Dhaka       0.00      0.00      0.00         1
#                                             Drum       0.67      0.67      0.67         3
#                             Education in the USA       0.64      0.75      0.69        12
#                                              Eel       1.00      0.50      0.67         2
#                                            Egypt       1.00      0.50      0.67         2
#                                             FIFA       0.62      0.89      0.73         9
#                                Facts about Kenya       1.00      1.00      1.00        10
#                                          Finland       1.00      0.75      0.86         4
#                                 Finnish_language       0.00      0.00      0.00         1
#                                            Flute       1.00      1.00      1.00         3
#                                      Food Trivia       0.15      0.70      0.25        10
#                                              Fox       1.00      0.33      0.50         3
#                                  French_language       0.00      0.00      0.00         1
#                                          G-Suite       1.00      0.57      0.73         7
#                                General Knowledge       0.15      0.40      0.22        10
#                                      Gerald_Ford       1.00      1.00      1.00         1
#                                  German_language       0.00      0.00      0.00         2
#                                            Ghana       1.00      0.50      0.67         4
#                                      Giant_Panda       0.67      0.67      0.67         3
#                                          Giraffe       1.00      1.00      1.00         1
#                                      Google Home       1.00      1.00      1.00         3
#                                 Google and Gmail       0.60      0.75      0.67         8
#                                        Gray_Wolf       1.00      0.50      0.67         2
#                                 Grover_Cleveland       1.00      0.75      0.86         4
#                                           Guitar       1.00      0.67      0.80         6
#                                  Henri_Becquerel       0.50      0.50      0.50         2
#                    History and facts about Ghana       0.75      0.55      0.63        11
#                                        Indonesia       0.80      1.00      0.89         4
#                              Internet of Things        0.86      0.86      0.86         7
#                                     Isaac_Newton       0.75      0.75      0.75         4
#                                          Jakarta       1.00      0.50      0.67         4
#                                     James_Monroe       1.00      1.00      1.00         2
#                                       James_Watt       0.56      0.83      0.67         6
#                                       John_Adams       1.00      0.71      0.83         7
#                                  Korean_language       0.50      1.00      0.67         2
#                                     Kuala_Lumpur       1.00      1.00      1.00         2
#                                    Liechtenstein       1.00      0.75      0.86         8
#                                             Lima       1.00      1.00      1.00         1
#                                          Lobster       1.00      0.50      0.67         4
#                                           London       0.00      0.00      0.00         1
#                                             Lyre       1.00      0.50      0.67         2
#                                   Malay_language       1.00      1.00      1.00         2
#                                        Melbourne       0.00      0.00      0.00         2
#                                  Michael_Faraday       1.00      0.38      0.55         8
#                                 Millard_Fillmore       1.00      1.00      1.00         6
#                                         Montreal       0.00      0.00      0.00         1
#                                          Nairobi       1.00      0.50      0.67         2
#                                           Nassau       0.00      0.00      0.00         1
#                                      Networking        0.33      0.56      0.42         9
#                                     Nikola_Tesla       1.00      0.75      0.86         4
#                                          Octopus       1.00      1.00      1.00         3
#                                           Ottawa       1.00      1.00      1.00         1
#                                            Otter       0.00      0.00      0.00         1
#                                            Piano       1.00      1.00      1.00         4
#                            Pierre-Auguste_Renoir       0.00      0.00      0.00         2
#                              Portuguese_language       1.00      0.50      0.67         4
#                          Prerequisites, Schedule       0.00      0.00      0.00         1
#                                            Qatar       1.00      0.50      0.67         4
#                                          Romania       1.00      1.00      1.00         4
#                                 Saint_Petersburg       0.00      0.00      0.00         5
#                Samsung's Digital Assistant Bixby       1.00      1.00      1.00        11
#                                    San_Francisco       0.00      0.00      0.00         1
#                                         Santiago       1.00      1.00      1.00         1
#                                        Singapore       1.00      0.50      0.67         6
#                                 Swahili_language       0.00      0.00      0.00         1
#                                             Swan       1.00      0.60      0.75         5
#                                 Swedish_language       0.00      0.00      0.00         3
#                                           Taipei       0.00      0.00      0.00         1
#                                   The Human Body       1.00      0.50      0.67         2
#                                 The Solar System       1.00      0.78      0.88         9
#                               Theodore_Roosevelt       1.00      1.00      1.00         3
#                                            Tiger       1.00      1.00      1.00         1
#                                          Trumpet       1.00      1.00      1.00         2
#                                           Turtle       0.00      0.00      0.00         1
#                                 Ulysses_S._Grant       1.00      1.00      1.00         3
#                         United States of America       0.38      0.83      0.53        12
#                                          Uruguay       1.00      0.67      0.80         6
#                                           Violin       1.00      1.00      1.00         3
#                                          Weather       1.00      0.50      0.67         2
#                                  Web Development       0.38      0.50      0.43         6
#                                   Woodrow_Wilson       1.00      1.00      1.00         4
#                                        Xylophone       1.00      0.40      0.57         5
#                                            Zebra       0.00      0.00      0.00         2
#                                           beetle       1.00      0.83      0.91         6
#                                             duck       0.50      1.00      0.67         1
#                                         elephant       1.00      0.75      0.86         4
#                                         kangaroo       1.00      1.00      1.00         5
#                                          leopard       1.00      1.00      1.00         2
#                                            otter       0.60      1.00      0.75         3
#                                          penguin       1.00      0.89      0.94         9
#                                       polar_bear       1.00      1.00      1.00         5
#                                           turtle       1.00      1.00      1.00         9
#
#                                      avg / total       0.76      0.69      0.69       522
# C:\Users\Zoe Tagboto\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
