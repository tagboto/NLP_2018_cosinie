# %%
#import math as m 
import re

# %%
def readFile(filename):
    allClasses = {}
    for line in open(filename):
        cleanLine = re.sub(r"[\n\t!';:&():?%$#+]","",line.lower())
        review = re.sub(r"[/,.-]"," ",cleanLine)
        #print(review)
        val = review[-1][-1]
        if val in allClasses:
            allClasses[val].append(review[:-1])
    
        else:
            allClasses[val] = [review[:-1]]
    print(allClasses)

readFile('imdb_labelled.txt')
# Out:
# {'0': ['a very  very  very slow moving  aimless movie about a distressed  drifting young man   ', 'not sure who was more lost   the flat characters or the audience  nearly half of whom walked out   ', 'attempting artiness with black  white and clever camera angles  the movie disappointed   became even more ridiculous   as the acting was poor and the plot and lines almost non existent   ', 'very little music or anything to speak of   ', 'the rest of the movie lacks art  charm  meaning    if its about emptiness  it works i guess because its empty   ', 'wasted two hours   ', 'a bit predictable   ', 'it had some average acting from the main person  and it was a low budget as you clearly can see   ', 'this short film certainly pulls no punches   ', 'graphics is far from the best part of the game   ', 'today the graphics are crap   ', 'this was a flick doomed from its conception   ', 'the very idea of it was lame   take a minor character from a mediocre pg 13 film  and make a complete non 
# ...
